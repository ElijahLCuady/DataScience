# %%
import pandas as pd

df = pd.read_csv("../datasets/alljobs.csv")

# %%
df.head()
# Out:
#                                            Job-Title Date-Posted
# 0  Bachelor of Science, Nursing Instructor   Part...  2023-04-25  \
# 1                               PHD Graduate Student  2023-04-19
# 2                           Central Graduate Advisor  2023-04-19
# 3                       Student/Graduate Application  2023-04-20
# 4  Advisor, Graduate Student Experience, Haskayne...  2023-04-12
#
#                  Company    Job-Type                  Salary        Location
# 0       Red Deer College   Full-time                     NaN    Red Deer, AB  \
# 1   IDOBE Research Group   Full-time                     NaN    Edmonton, AB
# 2  University of Alberta   Full-time  $47,210–$63,741 a year    Edmonton, AB
# 3      Eagle Builders LP  Internship                     NaN  Blackfalds, AB
# 4  University of Calgary   Full-time                     NaN     Calgary, AB
#
#                                          Description
# 0  Position Information\n\nPosition Title\n\nBach...
# ...

# %%
columns_to_set = set(df["Location"])


for val in columns_to_set:
    if "Oslo" in val:
        print(val, "FOUND")
# Out:
# Oslo, Norway (+1 other) FOUND
# Oslo, Norway (+3 others) FOUND
# Oslo, Norway FOUND
# Oslo, Norway (+5 others) FOUND

# %%
regional_jobs = df[df["Location"] == "Oslo, Norway"]
regional_jobs
# Out:
#                                                Job-Title Date-Posted
# 1780         Associate Professor in Religion and Society  2023-04-20  \
# 1817                               Lecturer in Nutrition  2023-04-20
# 9242                             Remote Data Entry Clerk  2023-04-06
# 9243   Data Entry Administrative Virtual Assistant Re...  2023-04-24
# 9246                                   Account Executive  2023-04-25
# ...                                                  ...         ...
# 34448                                  Community Manager         NaN
# 34456                      Equipment Buyer - Urgent Role  2023-03-29
# 34458                         Volunteer Language Teacher  2023-04-25
# 34460                     Volunteer 1-1 Language Teacher  2023-03-27
# 34461                                  Volunteer Teacher  2023-04-20
#
#                                   Company   Job-Type Salary      Location
# ...
